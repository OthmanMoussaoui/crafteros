# %% [markdown]
# # Soccer Object Detection

# %%
# Import libraries
import numpy as np
import pandas as pd

import cv2
import skimage
from PIL import Image
from ultralytics import YOLO
from sklearn.metrics import mean_squared_error

import json
import yaml
import time

# %%
# Get tactical map keypoints positions dictionary
json_path = "./pitch map labels position.json"
with open(json_path, 'r') as f:
    keypoints_map_pos = json.load(f)

# Get football field keypoints numerical to alphabetical mapping
yaml_path = "./config pitch dataset.yaml"
with open(yaml_path, 'r') as file:
    classes_names_dic = yaml.safe_load(file)
classes_names_dic = classes_names_dic['names']

# Get football field keypoints numerical to alphabetical mapping
yaml_path = "./config players dataset.yaml"
with open(yaml_path, 'r') as file:
    labels_dic = yaml.safe_load(file)
labels_dic = labels_dic['names']

print("Known coordinates of each keypoint on the tactical map:")
display(pd.DataFrame(keypoints_map_pos, index=['x','y']))
print("Numerical label of field keypoints (as defined when training the Yolo model):")
display(pd.Series(classes_names_dic, name='alpha_label').reset_index().rename({"index":"num_label"}, axis=1).set_index("alpha_label").transpose())
print("Numerical label of the player, referee, and ball objects (as defined when training the Yolo model):")
display(pd.Series(labels_dic, name='alpha_label').reset_index().rename({"index":"num_label"}, axis=1).set_index("alpha_label").transpose())
print('\033[1mThe dataframe representation are not used in what follows (original dictionary will be used)')
# Out:
# Known coordinates of each keypoint on the tactical map:
#    TLC  TRC  TR6MC  TL6MC  TR6ML  TL6ML  TR18MC  TL18MC  TR18ML  TL18ML  ...  \
# x   15  291    188    116    189    116     221      84     221      84  ...
# y   15   15     35     35     15     15      73      73      15      15  ...
#
#    BR6MC  BL6MC  BR6ML  BL6ML  BR18MC  BL18MC  BR18ML  BL18ML  BRArc  BLArc
# x    189    117    189    117     221      84     221      84    182    121
# y    501    501    521    521     463     463     521     521    463    463
#
# [2 rows x 28 columns]
# Numerical label of field keypoints (as defined when training the Yolo model):
# alpha_label  TLC  TRC  TR6MC  TL6MC  TR6ML  TL6ML  TR18MC  TL18MC  TR18ML  \
# num_label      0    1      2      3      4      5       6       7       8
#
# alpha_label  TL18ML  ...  BR6MC  BL6MC  BR6ML  BL6ML  BR18MC  BL18MC  BR18ML  \
# num_label         9  ...     18     19     20     21      22      23      24
#
# alpha_label  BL18ML  BRArc  BLArc
# num_label        25     26     27
#
# [1 rows x 28 columns]
# Numerical label of the player, referee, and ball objects (as defined when training the Yolo model):
# alpha_label  player  referee  ball
# num_label         0        1     2
# The dataframe representation are not used in what follows (original dictionary will be used)

# %%
# Set video path
video_path = './Alnasr_game.mp4'

# Read tactical map image
tac_map = cv2.imread('./tactical_map.jpg')

# Define team colors (based on chosen video)
nbr_team_colors = 2
colors_dic = {
    "Chelsea":[(41,71,138), (220,98,88)], # Chelsea colors (Players kit color, GK kit color)
    "Man City":[(144,200,255), (188,199,3)] # Man City colors (Players kit color, GK kit color)
}

colors_list = colors_dic["Chelsea"]+colors_dic["Man City"] # Define color list to be used for detected player team prediction
color_list_lab = [skimage.color.rgb2lab([i/255 for i in c]) for c in colors_list] # Converting color_list to L*a*b* space

# %%
# Load the YOLOv8 players detection model
model_players = YOLO("./models/Yolo8L Players/weights/best.pt")

# Load the YOLOv8 field keypoints detection model
model_keypoints = YOLO("./models/Yolo8M Field Keypoints/weights/best.pt")

# %%
# Open video file
cap = cv2.VideoCapture(video_path)

# Initialize frame counter
frame_nbr = 0

# Set keypoints average displacement tolerance level (in pixels) [set to -1 to always update homography matrix]
keypoints_displacement_mean_tol = 10

# Set confidence thresholds for players and field keypoints detections
player_model_conf_thresh = 0.60
keypoints_model_conf_thresh = 0.70

# Set variable to record the time when we processed last frame 
prev_frame_time = 0
# Set variable to record the time at which we processed current frame 
new_frame_time = 0

# Store the ball track history
ball_track_history = {'src':[],
                      'dst':[]
}

# Count consecutive frames with no ball detected
nbr_frames_no_ball = 0
# Threshold for number of frames with no ball to reset ball track (frames)
nbr_frames_no_ball_thresh = 30
# Distance threshold for ball tracking (pixels)
ball_track_dist_thresh = 100
# Maximum ball track length (detections)
max_track_length = 35

# Loop through the video frames
while cap.isOpened():

    # Update frame counter
    frame_nbr += 1

    # Read a frame from the video
    success, frame = cap.read()

    # Reset tactical map image for each new frame
    tac_map_copy = tac_map.copy()

    # Reset ball tracks
    if nbr_frames_no_ball>nbr_frames_no_ball_thresh:
            ball_track_history['dst'] = []
            ball_track_history['src'] = []

    # Process the frame if it was successfuly read
    if success:
        
        #################### Part 1 ####################
        # Object Detection & Coordiante Transofrmation #
        ################################################

        # Run YOLOv8 players inference on the frame
        results_players = model_players(frame, conf=player_model_conf_thresh)
        # Run YOLOv8 field keypoints inference on the frame
        results_keypoints = model_keypoints(frame, conf=keypoints_model_conf_thresh)

        ## Extract detections information
        bboxes_p = results_players[0].boxes.xyxy.cpu().numpy()                          # Detected players, referees and ball (x,y,x,y) bounding boxes
        bboxes_p_c = results_players[0].boxes.xywh.cpu().numpy()                        # Detected players, referees and ball (x,y,w,h) bounding boxes    
        labels_p = list(results_players[0].boxes.cls.cpu().numpy())                     # Detected players, referees and ball labels list
        confs_p = list(results_players[0].boxes.conf.cpu().numpy())                     # Detected players, referees and ball confidence level
        
        bboxes_k = results_keypoints[0].boxes.xyxy.cpu().numpy()                        # Detected field keypoints (x,y,w,h) bounding boxes
        bboxes_k_c = results_keypoints[0].boxes.xywh.cpu().numpy()                        # Detected field keypoints (x,y,w,h) bounding boxes
        labels_k = list(results_keypoints[0].boxes.cls.cpu().numpy())                   # Detected field keypoints labels list

        # Convert detected numerical labels to alphabetical labels
        detected_labels = [classes_names_dic[i] for i in labels_k]

        # Extract detected field keypoints coordiantes on the current frame
        detected_labels_src_pts = np.array([list(np.round(bboxes_k_c[i][:2]).astype(int)) for i in range(bboxes_k_c.shape[0])])

        # Get the detected field keypoints coordinates on the tactical map
        detected_labels_dst_pts = np.array([keypoints_map_pos[i] for i in detected_labels])


        ## Calculate Homography transformation matrix when more than 4 keypoints are detected
        if len(detected_labels) > 3:
            # Always calculate homography matrix on the first frame
            if frame_nbr > 1:
                # Determine common detected field keypoints between previous and current frames
                common_labels = set(detected_labels_prev) & set(detected_labels)
                # When at least 4 common keypoints are detected, determine if they are displaced on average beyond a certain tolerance level
                if len(common_labels) > 3:
                    common_label_idx_prev = [detected_labels_prev.index(i) for i in common_labels]   # Get labels indexes of common detected keypoints from previous frame
                    common_label_idx_curr = [detected_labels.index(i) for i in common_labels]        # Get labels indexes of common detected keypoints from current frame
                    coor_common_label_prev = detected_labels_src_pts_prev[common_label_idx_prev]     # Get labels coordiantes of common detected keypoints from previous frame
                    coor_common_label_curr = detected_labels_src_pts[common_label_idx_curr]          # Get labels coordiantes of common detected keypoints from current frame
                    coor_error = mean_squared_error(coor_common_label_prev, coor_common_label_curr)  # Calculate error between previous and current common keypoints coordinates
                    update_homography = coor_error > keypoints_displacement_mean_tol                 # Check if error surpassed the predefined tolerance level
                else:
                    update_homography = True                                                         
            else:
                update_homography = True

            if  update_homography:
                h, mask = cv2.findHomography(detected_labels_src_pts,                   # Calculate homography matrix
                                              detected_labels_dst_pts)                  
            
            detected_labels_prev = detected_labels.copy()                               # Save current detected keypoint labels for next frame
            detected_labels_src_pts_prev = detected_labels_src_pts.copy()               # Save current detected keypoint coordiantes for next frame

            bboxes_p_c_0 = bboxes_p_c[[i==0 for i in labels_p],:]                       # Get bounding boxes information (x,y,w,h) of detected players (label 0)
            bboxes_p_c_2 = bboxes_p_c[[i==2 for i in labels_p],:]                       # Get bounding boxes information (x,y,w,h) of detected ball(s) (label 2)

            # Get coordinates of detected players on frame (x_cencter, y_center+h/2)
            detected_ppos_src_pts = bboxes_p_c_0[:,:2]  + np.array([[0]*bboxes_p_c_0.shape[0], bboxes_p_c_0[:,3]/2]).transpose()
            # Get coordinates of the first detected ball (x_center, y_center)
            detected_ball_src_pos = bboxes_p_c_2[0,:2] if bboxes_p_c_2.shape[0]>0 else None

            # Transform players coordinates from frame plane to tactical map plance using the calculated Homography matrix
            pred_dst_pts = []                                                           # Initialize players tactical map coordiantes list
            for pt in detected_ppos_src_pts:                                            # Loop over players frame coordiantes
                pt = np.append(np.array(pt), np.array([1]), axis=0)                     # Covert to homogeneous coordiantes
                dest_point = np.matmul(h, np.transpose(pt))                              # Apply homography transofrmation
                dest_point = dest_point/dest_point[2]                                   # Revert to 2D-coordiantes
                pred_dst_pts.append(list(np.transpose(dest_point)[:2]))                 # Update players tactical map coordiantes list
            pred_dst_pts = np.array(pred_dst_pts)

            # Transform ball coordinates from frame plane to tactical map plane using the calculated Homography matrix
            if detected_ball_src_pos is not None:
                pt = np.append(np.array(detected_ball_src_pos), np.array([1]), axis=0)
                dest_point = np.matmul(h, np.transpose(pt))
                dest_point = dest_point/dest_point[2]
                detected_ball_dst_pos = np.transpose(dest_point)

                # Update track ball position history
                if len(ball_track_history['src'])>0 :
                    if np.linalg.norm(detected_ball_src_pos-ball_track_history['src'][-1])<ball_track_dist_thresh:
                        ball_track_history['src'].append((int(detected_ball_src_pos[0]), int(detected_ball_src_pos[1])))
                        ball_track_history['dst'].append((int(detected_ball_dst_pos[0]), int(detected_ball_dst_pos[1])))
                    else:
                        ball_track_history['src']=[(int(detected_ball_src_pos[0]), int(detected_ball_src_pos[1]))]
                        ball_track_history['dst']=[(int(detected_ball_dst_pos[0]), int(detected_ball_dst_pos[1]))]
                else:
                    ball_track_history['src'].append((int(detected_ball_src_pos[0]), int(detected_ball_src_pos[1])))
                    ball_track_history['dst'].append((int(detected_ball_dst_pos[0]), int(detected_ball_dst_pos[1])))
            # Remove oldest tracked ball postion if track exceedes threshold        
            if len(ball_track_history) > max_track_length:
                    ball_track_history['src'].pop(0)
                    ball_track_history['dst'].pop(0)

        ######### Part 2 ########## 
        # Players Team Prediction #
        ###########################

        frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)                                      # Convert frame to RGB
        obj_palette_list = []                                                                   # Initialize players color palette list
        palette_interval = (0,5)                                                                # Color interval to extract from dominant colors palette (1rd to 5th color)
        annotated_frame = frame                                                                 # Create annotated frame 

        ## Loop over detected players (label 0) and extract dominant colors palette based on defined interval
        for i, j in enumerate(list(results_players[0].boxes.cls.cpu().numpy())):
            if int(j) == 0:
                bbox = results_players[0].boxes.xyxy.cpu().numpy()[i,:]                         # Get bbox info (x,y,x,y)
                obj_img = frame_rgb[int(bbox[1]):int(bbox[3]), int(bbox[0]):int(bbox[2])]       # Crop bbox out of the frame
                obj_img_w, obj_img_h = obj_img.shape[1], obj_img.shape[0]
                center_filter_x1 = np.max([(obj_img_w//2)-(obj_img_w//5), 1])
                center_filter_x2 = (obj_img_w//2)+(obj_img_w//5)
                center_filter_y1 = np.max([(obj_img_h//3)-(obj_img_h//5), 1])
                center_filter_y2 = (obj_img_h//3)+(obj_img_h//5)
                center_filter = obj_img[center_filter_y1:center_filter_y2, 
                                        center_filter_x1:center_filter_x2]
                obj_pil_img = Image.fromarray(np.uint8(center_filter))                          # Convert to pillow image
                    
                reduced = obj_pil_img.convert("P", palette=Image.Palette.WEB)                   # Convert to web palette (216 colors)
                palette = reduced.getpalette()                                                  # Get palette as [r,g,b,r,g,b,...]
                palette = [palette[3*n:3*n+3] for n in range(256)]                              # Group 3 by 3 = [[r,g,b],[r,g,b],...]
                color_count = [(n, palette[m]) for n,m in reduced.getcolors()]                  # Create list of palette colors with their frequency
                RGB_df = pd.DataFrame(color_count, columns = ['cnt', 'RGB']).sort_values(       # Create dataframe based on defined palette interval
                                      by = 'cnt', ascending = False).iloc[
                                          palette_interval[0]:palette_interval[1],:]
                palette = list(RGB_df.RGB)                                                      # Convert palette to list (for faster processing)
                annotated_frame = cv2.rectangle(annotated_frame,                                # Add center filter bbox annotations
                                                (int(bbox[0])+center_filter_x1, 
                                                 int(bbox[1])+ center_filter_y1),  
                                                (int(bbox[0])+center_filter_x2, 
                                                 int(bbox[1])+center_filter_y2), (0,0,0), 2)
                
                # Update detected players color palette list
                obj_palette_list.append(palette)
        
        ## Calculate distances between each color from every detected player color palette and the predefined teams colors
        players_distance_features = []
        # Loop over detected players extracted color palettes
        for palette in obj_palette_list:
            palette_distance = []
            palette_lab = [skimage.color.rgb2lab([i/255 for i in color]) for color in palette]  # Convert colors to L*a*b* space
            # Loop over colors in palette
            for color in palette_lab:
                distance_list = []
                # Loop over predefined list of teams colors
                for c in color_list_lab:
                    #distance = np.linalg.norm([i/255 - j/255 for i,j in zip(color,c)])
                    distance = skimage.color.deltaE_cie76(color, c)                             # Calculate Euclidean distance in Lab color space
                    distance_list.append(distance)                                              # Update distance list for current color
                palette_distance.append(distance_list)                                          # Update distance list for current palette
            players_distance_features.append(palette_distance)                                  # Update distance features list

        ## Predict detected players teams based on distance features
        players_teams_list = []
        # Loop over players distance features
        for distance_feats in players_distance_features:
            vote_list=[]
            # Loop over distances for each color 
            for dist_list in distance_feats:
                team_idx = dist_list.index(min(dist_list))//nbr_team_colors                     # Assign team index for current color based on min distance
                vote_list.append(team_idx)                                                      # Update vote voting list with current color team prediction
            players_teams_list.append(max(vote_list, key=vote_list.count))                      # Predict current player team by vote counting


        #################### Part 3 #####################
        # Updated Frame & Tactical Map With Annotations #
        #################################################

        ball_color_bgr = (0,0,255)                                                                          # Color (GBR) for ball annotation on tactical map
        j=0                                                                                                 # Initializing counter of detected players
        palette_box_size = 10                                                                               # Set color box size in pixels (for display)
        

        # Loop over all detected object by players detection model
        for i in range(bboxes_p.shape[0]):
            conf = confs_p[i]                                                                               # Get confidence of current detected object
            if labels_p[i]==0:                                                                              # Display annotation for detected players (label 0)
                
                # Display extracted color palette for each detected player
                palette = obj_palette_list[j]                                                               # Get color palette of the detected player
                for k, c in enumerate(palette):
                    c_bgr = c[::-1]                                                                         # Convert color to BGR
                    annotated_frame = cv2.rectangle(annotated_frame, (int(bboxes_p[i,2])+3,                 # Add color palette annotation on frame
                                                            int(bboxes_p[i,1])+k*palette_box_size),
                                                            (int(bboxes_p[i,2])+palette_box_size,
                                                            int(bboxes_p[i,1])+(palette_box_size)*(k+1)),
                                                              c_bgr, -1)

                team_name = list(colors_dic.keys())[players_teams_list[j]]                                  # Get detected player team prediction
                color_rgb = colors_dic[team_name][0]                                                        # Get detected player team color
                color_bgr = color_rgb[::-1]                                                                 # Convert color to bgr

                annotated_frame = cv2.rectangle(annotated_frame, (int(bboxes_p[i,0]), int(bboxes_p[i,1])),  # Add bbox annotations with team colors
                                                (int(bboxes_p[i,2]), int(bboxes_p[i,3])), color_bgr, 1)
                
                cv2.putText(annotated_frame, team_name + f" {conf:.2f}",                                    # Add team name annotations
                             (int(bboxes_p[i,0]), int(bboxes_p[i,1])-10), cv2.FONT_HERSHEY_SIMPLEX, 0.5,
                               color_bgr, 2)
                
                # Add tactical map player postion color coded annotation if more than 3 field keypoints are detected
                if len(detected_labels_src_pts)>3:
                    tac_map_copy = cv2.circle(tac_map_copy, (int(pred_dst_pts[j][0]),int(pred_dst_pts[j][1])),
                                          radius=5, color=color_bgr, thickness=-1)

                j+=1                                                                                        # Update players counter
            else:                                                                                           # Display annotation for otehr detections (label 1, 2)
                annotated_frame = cv2.rectangle(annotated_frame, (int(bboxes_p[i,0]), int(bboxes_p[i,1])),  # Add white colored bbox annotations
                                                 (int(bboxes_p[i,2]), int(bboxes_p[i,3])), (255,255,255), 1)
                cv2.putText(annotated_frame, labels_dic[labels_p[i]] + f" {conf:.2f}",                      # Add white colored label text annotations
                            (int(bboxes_p[i,0]), int(bboxes_p[i,1])-10), cv2.FONT_HERSHEY_SIMPLEX, 0.5,
                              (255,255,255), 2)

                # Add tactical map ball postion annotation if detected
                if detected_ball_src_pos is not None:
                    tac_map_copy = cv2.circle(tac_map_copy, (int(detected_ball_dst_pos[0]), 
                                                   int(detected_ball_dst_pos[1])), radius=5, 
                                                   color=ball_color_bgr, thickness=3)
        for i in range(bboxes_k.shape[0]):
            annotated_frame = cv2.rectangle(annotated_frame, (int(bboxes_k[i,0]), int(bboxes_k[i,1])),  # Add bbox annotations with team colors
                                        (int(bboxes_k[i,2]), int(bboxes_k[i,3])), (0,0,0), 1)
        
        # Plot the ball tracks on tactical map
        if len(ball_track_history['src'])>0:
            points = np.hstack(ball_track_history['dst']).astype(np.int32).reshape((-1, 1, 2))
            tac_map_copy = cv2.polylines(tac_map_copy, [points], isClosed=False, color=(0, 0, 100), thickness=2)
        
        # Combine annotated frame and tactical map in one image with colored border separation
        border_color = [255,255,255]                                                                        # Set border color (BGR)
        annotated_frame=cv2.copyMakeBorder(annotated_frame, 40, 10, 10, 10,                                 # Add borders to annotated frame
                                            cv2.BORDER_CONSTANT, value=border_color)
        tac_map_copy = cv2.copyMakeBorder(tac_map_copy, 70, 50, 10, 10, cv2.BORDER_CONSTANT,                # Add borders to tactical map 
                                           value=border_color)      
        tac_map_copy = cv2.resize(tac_map_copy, (tac_map_copy.shape[1], annotated_frame.shape[0]))          # Resize tactical map
        final_img = cv2.hconcat((annotated_frame, tac_map_copy))                                            # Concatenate both images
        ## Add info annotation
        cv2.putText(final_img, "Tactical Map", (1370,60), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0,0,0), 2)
        cv2.putText(final_img, "Press 'p' to pause & 'q' to quit", (820,30), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0,0,0), 2)

        new_frame_time = time.time()                                                                        # Get time after finished processing current frame
        fps = 1/(new_frame_time-prev_frame_time)                                                            # Calculate FPS as 1/(frame proceesing duration)
        prev_frame_time = new_frame_time                                                                    # Save current time to be used in next frame
        cv2.putText(final_img, "FPS: " + str(int(fps)), (20,30), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0,0,0), 2)
        
        # Display the final annotated frame
        cv2.imshow("YOLOv8 Players and Field Keypoints Detection with Team Prediction and Tactical Map",    
                    final_img)

        # Treat keyboard user inputs ("p" for pause/unpause & "q" for quit)
        key = cv2.waitKey(1)
        # Break the loop if 'q' is pressed
        if key == ord("q"):
            break
        if key == ord('p'):
            cv2.waitKey(-1) #wait until any key is pressed
    else:
        # Break the loop if the end of the video is reached
        break

# Release the video capture object and close the display window
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 320x640 14 players, 1 referee, 1567.4ms
# Speed: 17.5ms preprocess, 1567.4ms inference, 3.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 563.0ms
# Speed: 5.3ms preprocess, 563.0ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 players, 1 referee, 1097.5ms
# Speed: 6.0ms preprocess, 1097.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 481.9ms
# Speed: 4.7ms preprocess, 481.9ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 players, 1 referee, 1542.3ms
# Speed: 4.3ms preprocess, 1542.3ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 486.2ms
# Speed: 5.7ms preprocess, 486.2ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 players, 1 referee, 859.3ms
# Speed: 5.1ms preprocess, 859.3ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 593.3ms
# Speed: 4.7ms preprocess, 593.3ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 players, 1 referee, 1089.4ms
# Speed: 4.2ms preprocess, 1089.4ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 466.1ms
# Speed: 5.0ms preprocess, 466.1ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 players, 1 referee, 1023.4ms
# Speed: 5.5ms preprocess, 1023.4ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 703.0ms
# Speed: 5.0ms preprocess, 703.0ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 players, 1 referee, 992.7ms
# Speed: 5.8ms preprocess, 992.7ms inference, 3.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 581.4ms
# Speed: 4.9ms preprocess, 581.4ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 players, 1 referee, 880.5ms
# Speed: 5.6ms preprocess, 880.5ms inference, 2.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 625.4ms
# Speed: 7.2ms preprocess, 625.4ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 players, 1 referee, 884.0ms
# Speed: 4.2ms preprocess, 884.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 460.2ms
# Speed: 6.6ms preprocess, 460.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 players, 1 referee, 904.3ms
# Speed: 4.5ms preprocess, 904.3ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 450.2ms
# Speed: 4.5ms preprocess, 450.2ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 players, 1 referee, 841.0ms
# Speed: 4.5ms preprocess, 841.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 570.3ms
# Speed: 4.3ms preprocess, 570.3ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 players, 1 referee, 848.5ms
# Speed: 4.3ms preprocess, 848.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 466.6ms
# Speed: 5.7ms preprocess, 466.6ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 players, 1 referee, 840.5ms
# Speed: 4.1ms preprocess, 840.5ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 446.3ms
# Speed: 4.6ms preprocess, 446.3ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 players, 1 referee, 838.6ms
# Speed: 6.2ms preprocess, 838.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 503.3ms
# Speed: 6.4ms preprocess, 503.3ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 players, 1 referee, 857.5ms
# Speed: 5.5ms preprocess, 857.5ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 488.5ms
# Speed: 4.3ms preprocess, 488.5ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 players, 1 referee, 858.2ms
# Speed: 5.5ms preprocess, 858.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 442.4ms
# Speed: 5.9ms preprocess, 442.4ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 players, 1 referee, 910.4ms
# Speed: 5.6ms preprocess, 910.4ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 531.9ms
# Speed: 5.9ms preprocess, 531.9ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 players, 1 referee, 1080.0ms
# Speed: 5.8ms preprocess, 1080.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 478.3ms
# Speed: 5.0ms preprocess, 478.3ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 players, 1 referee, 967.7ms
# Speed: 4.4ms preprocess, 967.7ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 492.8ms
# Speed: 5.0ms preprocess, 492.8ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 players, 1 referee, 1304.1ms
# Speed: 4.1ms preprocess, 1304.1ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 571.4ms
# Speed: 6.0ms preprocess, 571.4ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 players, 1 referee, 951.0ms
# Speed: 4.9ms preprocess, 951.0ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 475.3ms
# Speed: 5.7ms preprocess, 475.3ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 players, 1 referee, 901.7ms
# Speed: 4.9ms preprocess, 901.7ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 462.7ms
# Speed: 4.1ms preprocess, 462.7ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 players, 1 referee, 901.9ms
# Speed: 5.8ms preprocess, 901.9ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 524.6ms
# Speed: 5.4ms preprocess, 524.6ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 players, 1 referee, 887.6ms
# Speed: 5.0ms preprocess, 887.6ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 503.7ms
# Speed: 5.4ms preprocess, 503.7ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 players, 1 referee, 868.7ms
# Speed: 5.2ms preprocess, 868.7ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 466.8ms
# Speed: 5.2ms preprocess, 466.8ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 players, 1 referee, 858.3ms
# Speed: 4.2ms preprocess, 858.3ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 564.3ms
# Speed: 6.0ms preprocess, 564.3ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 players, 1 referee, 895.9ms
# Speed: 4.4ms preprocess, 895.9ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 555.2ms
# Speed: 5.2ms preprocess, 555.2ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 players, 1 referee, 931.5ms
# Speed: 5.7ms preprocess, 931.5ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 463.2ms
# Speed: 6.1ms preprocess, 463.2ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 players, 1 referee, 856.8ms
# Speed: 4.4ms preprocess, 856.8ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 551.9ms
# Speed: 5.3ms preprocess, 551.9ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 players, 1 referee, 894.8ms
# Speed: 4.4ms preprocess, 894.8ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 466.6ms
# Speed: 4.3ms preprocess, 466.6ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 players, 1 referee, 840.5ms
# Speed: 5.6ms preprocess, 840.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 448.0ms
# Speed: 4.7ms preprocess, 448.0ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 players, 1 referee, 901.7ms
# Speed: 5.2ms preprocess, 901.7ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 628.7ms
# Speed: 4.5ms preprocess, 628.7ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 players, 1 referee, 893.3ms
# Speed: 5.1ms preprocess, 893.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 456.2ms
# Speed: 5.1ms preprocess, 456.2ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 players, 1 referee, 852.4ms
# Speed: 5.3ms preprocess, 852.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 445.9ms
# Speed: 5.4ms preprocess, 445.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 15 players, 1 referee, 1184.4ms
# Speed: 5.1ms preprocess, 1184.4ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 662.5ms
# Speed: 5.5ms preprocess, 662.5ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 players, 1 referee, 887.5ms
# Speed: 6.3ms preprocess, 887.5ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 489.5ms
# Speed: 4.2ms preprocess, 489.5ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 players, 1 referee, 930.8ms
# Speed: 5.7ms preprocess, 930.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 462.6ms
# Speed: 4.1ms preprocess, 462.6ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 players, 1 referee, 906.4ms
# Speed: 5.2ms preprocess, 906.4ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 540.1ms
# Speed: 6.6ms preprocess, 540.1ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 players, 1 referee, 872.9ms
# Speed: 5.1ms preprocess, 872.9ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 446.8ms
# Speed: 5.3ms preprocess, 446.8ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 players, 1 referee, 849.2ms
# Speed: 4.2ms preprocess, 849.2ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 479.0ms
# Speed: 4.1ms preprocess, 479.0ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 players, 1 referee, 864.5ms
# Speed: 4.8ms preprocess, 864.5ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 561.1ms
# Speed: 5.4ms preprocess, 561.1ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 players, 1 referee, 896.1ms
# Speed: 4.3ms preprocess, 896.1ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 459.1ms
# Speed: 5.5ms preprocess, 459.1ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 players, 1 referee, 853.8ms
# Speed: 4.2ms preprocess, 853.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 460.4ms
# Speed: 5.0ms preprocess, 460.4ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 16 players, 1 referee, 855.7ms
# Speed: 6.1ms preprocess, 855.7ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 536.2ms
# Speed: 5.2ms preprocess, 536.2ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 17 players, 1 referee, 857.9ms
# Speed: 5.0ms preprocess, 857.9ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 458.2ms
# Speed: 4.4ms preprocess, 458.2ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 17 players, 1 referee, 890.4ms
# Speed: 5.7ms preprocess, 890.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 455.8ms
# Speed: 5.5ms preprocess, 455.8ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 16 players, 2 referees, 858.3ms
# Speed: 4.2ms preprocess, 858.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 494.7ms
# Speed: 4.3ms preprocess, 494.7ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 17 players, 1 referee, 868.2ms
# Speed: 6.9ms preprocess, 868.2ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 440.8ms
# Speed: 4.1ms preprocess, 440.8ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 players, 1 referee, 851.2ms
# Speed: 4.4ms preprocess, 851.2ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 453.1ms
# Speed: 5.0ms preprocess, 453.1ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 15 players, 1 referee, 918.9ms
# Speed: 4.1ms preprocess, 918.9ms inference, 2.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 438.3ms
# Speed: 4.4ms preprocess, 438.3ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 16 players, 1 referee, 939.5ms
# Speed: 5.5ms preprocess, 939.5ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 460.2ms
# Speed: 5.4ms preprocess, 460.2ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 16 players, 1 referee, 856.2ms
# Speed: 5.0ms preprocess, 856.2ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 564.3ms
# Speed: 4.4ms preprocess, 564.3ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 15 players, 1 referee, 846.9ms
# Speed: 6.7ms preprocess, 846.9ms inference, 2.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 468.9ms
# Speed: 4.9ms preprocess, 468.9ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 16 players, 1 referee, 967.4ms
# Speed: 6.5ms preprocess, 967.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 485.6ms
# Speed: 4.2ms preprocess, 485.6ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 15 players, 1 referee, 850.3ms
# Speed: 4.5ms preprocess, 850.3ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 665.1ms
# Speed: 5.3ms preprocess, 665.1ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 15 players, 2 referees, 854.1ms
# Speed: 6.9ms preprocess, 854.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 454.9ms
# Speed: 4.1ms preprocess, 454.9ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 15 players, 1 referee, 1061.4ms
# Speed: 7.5ms preprocess, 1061.4ms inference, 2.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 593.9ms
# Speed: 6.1ms preprocess, 593.9ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 15 players, 1 referee, 1116.2ms
# Speed: 4.3ms preprocess, 1116.2ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 497.9ms
# Speed: 4.2ms preprocess, 497.9ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 13 players, 1 referee, 853.2ms
# Speed: 4.2ms preprocess, 853.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 508.7ms
# Speed: 5.6ms preprocess, 508.7ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 players, 2 referees, 880.1ms
# Speed: 5.2ms preprocess, 880.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 436.1ms
# Speed: 4.1ms preprocess, 436.1ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 13 players, 2 referees, 852.6ms
# Speed: 5.7ms preprocess, 852.6ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 460.6ms
# Speed: 4.1ms preprocess, 460.6ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 players, 1 referee, 867.4ms
# Speed: 5.8ms preprocess, 867.4ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 444.9ms
# Speed: 4.2ms preprocess, 444.9ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 players, 1 referee, 930.4ms
# Speed: 7.3ms preprocess, 930.4ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 452.1ms
# Speed: 4.7ms preprocess, 452.1ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 players, 1 referee, 841.4ms
# Speed: 4.4ms preprocess, 841.4ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 474.5ms
# Speed: 4.2ms preprocess, 474.5ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 13 players, 1 referee, 849.1ms
# Speed: 5.2ms preprocess, 849.1ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 448.2ms
# Speed: 4.7ms preprocess, 448.2ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 players, 1 referee, 974.7ms
# Speed: 6.6ms preprocess, 974.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 477.6ms
# Speed: 6.1ms preprocess, 477.6ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 players, 1 referee, 837.9ms
# Speed: 4.9ms preprocess, 837.9ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 436.6ms
# Speed: 4.6ms preprocess, 436.6ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 players, 1 referee, 1001.6ms
# Speed: 6.4ms preprocess, 1001.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 469.5ms
# Speed: 4.4ms preprocess, 469.5ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 players, 1 referee, 955.7ms
# Speed: 5.4ms preprocess, 955.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 455.8ms
# Speed: 6.2ms preprocess, 455.8ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 players, 1 referee, 852.4ms
# Speed: 4.2ms preprocess, 852.4ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 449.8ms
# Speed: 4.5ms preprocess, 449.8ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 players, 1 referee, 855.1ms
# Speed: 4.1ms preprocess, 855.1ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 438.0ms
# Speed: 4.4ms preprocess, 438.0ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 15 players, 1 referee, 943.5ms
# Speed: 5.9ms preprocess, 943.5ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 471.6ms
# Speed: 5.5ms preprocess, 471.6ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 15 players, 1 referee, 851.9ms
# Speed: 6.1ms preprocess, 851.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 448.1ms
# Speed: 4.1ms preprocess, 448.1ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 15 players, 1 referee, 843.8ms
# Speed: 5.7ms preprocess, 843.8ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 441.4ms
# Speed: 5.1ms preprocess, 441.4ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 15 players, 1 referee, 873.3ms
# Speed: 6.1ms preprocess, 873.3ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 550.2ms
# Speed: 7.1ms preprocess, 550.2ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 players, 2 referees, 875.7ms
# Speed: 5.2ms preprocess, 875.7ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 437.7ms
# Speed: 4.1ms preprocess, 437.7ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 13 players, 1 referee, 852.0ms
# Speed: 6.2ms preprocess, 852.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 449.2ms
# Speed: 4.6ms preprocess, 449.2ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 15 players, 1 referee, 854.9ms
# Speed: 4.3ms preprocess, 854.9ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 569.4ms
# Speed: 4.1ms preprocess, 569.4ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 15 players, 1 referee, 1059.2ms
# Speed: 7.6ms preprocess, 1059.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 483.1ms
# Speed: 5.2ms preprocess, 483.1ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 15 players, 1 referee, 864.5ms
# Speed: 5.9ms preprocess, 864.5ms inference, 2.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 450.8ms
# Speed: 4.3ms preprocess, 450.8ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 15 players, 1 referee, 849.9ms
# Speed: 6.9ms preprocess, 849.9ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 562.6ms
# Speed: 4.9ms preprocess, 562.6ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 15 players, 1 referee, 875.0ms
# Speed: 5.3ms preprocess, 875.0ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 445.4ms
# Speed: 4.1ms preprocess, 445.4ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 15 players, 1 referee, 851.4ms
# Speed: 4.2ms preprocess, 851.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 441.5ms
# Speed: 5.9ms preprocess, 441.5ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 15 players, 1 referee, 823.6ms
# Speed: 6.4ms preprocess, 823.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 477.6ms
# Speed: 5.8ms preprocess, 477.6ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 15 players, 1 referee, 956.0ms
# Speed: 7.4ms preprocess, 956.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 441.0ms
# Speed: 5.7ms preprocess, 441.0ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 15 players, 1 referee, 853.3ms
# Speed: 5.2ms preprocess, 853.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 476.3ms
# Speed: 4.1ms preprocess, 476.3ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 15 players, 1 referee, 833.9ms
# Speed: 6.6ms preprocess, 833.9ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 445.0ms
# Speed: 4.3ms preprocess, 445.0ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 players, 1 referee, 939.1ms
# Speed: 4.6ms preprocess, 939.1ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 492.6ms
# Speed: 4.9ms preprocess, 492.6ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 15 players, 1 referee, 844.0ms
# Speed: 5.0ms preprocess, 844.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 440.3ms
# Speed: 4.5ms preprocess, 440.3ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 15 players, 1 referee, 856.6ms
# Speed: 4.1ms preprocess, 856.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 442.1ms
# Speed: 4.1ms preprocess, 442.1ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 16 players, 1 referee, 1045.4ms
# Speed: 5.2ms preprocess, 1045.4ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 494.7ms
# Speed: 11.5ms preprocess, 494.7ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 15 players, 1 referee, 855.6ms
# Speed: 4.2ms preprocess, 855.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 LMC, 443.8ms
# Speed: 4.1ms preprocess, 443.8ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 players, 2 referees, 882.5ms
# Speed: 5.3ms preprocess, 882.5ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 459.5ms
# Speed: 4.6ms preprocess, 459.5ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 15 players, 2 referees, 970.6ms
# Speed: 5.4ms preprocess, 970.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 440.4ms
# Speed: 4.1ms preprocess, 440.4ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 15 players, 1 referee, 854.4ms
# Speed: 6.2ms preprocess, 854.4ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 465.7ms
# Speed: 5.7ms preprocess, 465.7ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 15 players, 2 referees, 836.3ms
# Speed: 4.7ms preprocess, 836.3ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 LMC, 450.4ms
# Speed: 4.9ms preprocess, 450.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 players, 1 referee, 953.6ms
# Speed: 18.0ms preprocess, 953.6ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 449.5ms
# Speed: 6.7ms preprocess, 449.5ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 15 players, 1 referee, 852.0ms
# Speed: 4.2ms preprocess, 852.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 441.5ms
# Speed: 5.4ms preprocess, 441.5ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 players, 1 referee, 852.3ms
# Speed: 5.2ms preprocess, 852.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 440.8ms
# Speed: 4.2ms preprocess, 440.8ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 players, 1 referee, 878.4ms
# Speed: 4.5ms preprocess, 878.4ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 814.4ms
# Speed: 7.1ms preprocess, 814.4ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 15 players, 1 referee, 951.8ms
# Speed: 5.4ms preprocess, 951.8ms inference, 2.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 LMC, 498.0ms
# Speed: 4.1ms preprocess, 498.0ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 15 players, 1 referee, 968.8ms
# Speed: 5.2ms preprocess, 968.8ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 LMC, 480.9ms
# Speed: 4.9ms preprocess, 480.9ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 15 players, 1 referee, 996.5ms
# Speed: 5.4ms preprocess, 996.5ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 468.6ms
# Speed: 5.2ms preprocess, 468.6ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 15 players, 1 referee, 1519.4ms
# Speed: 4.6ms preprocess, 1519.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 1040.2ms
# Speed: 6.1ms preprocess, 1040.2ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 16 players, 1 referee, 1196.7ms
# Speed: 4.4ms preprocess, 1196.7ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 LMC, 491.1ms
# Speed: 7.6ms preprocess, 491.1ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 16 players, 1 referee, 944.3ms
# Speed: 6.1ms preprocess, 944.3ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 LMC, 487.8ms
# Speed: 4.3ms preprocess, 487.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 15 players, 1 referee, 918.5ms
# Speed: 6.0ms preprocess, 918.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 864.2ms
# Speed: 4.1ms preprocess, 864.2ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 15 players, 1 referee, 1337.2ms
# Speed: 4.5ms preprocess, 1337.2ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 810.1ms
# Speed: 6.0ms preprocess, 810.1ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 15 players, 1 referee, 1075.4ms
# Speed: 6.8ms preprocess, 1075.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 516.3ms
# Speed: 8.3ms preprocess, 516.3ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 15 players, 1 referee, 871.4ms
# Speed: 4.2ms preprocess, 871.4ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 498.4ms
# Speed: 5.4ms preprocess, 498.4ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 15 players, 1 referee, 843.3ms
# Speed: 4.1ms preprocess, 843.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 431.1ms
# Speed: 5.1ms preprocess, 431.1ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 15 players, 1 referee, 828.6ms
# Speed: 5.0ms preprocess, 828.6ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 461.9ms
# Speed: 4.6ms preprocess, 461.9ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 players, 1 referee, 833.2ms
# Speed: 4.3ms preprocess, 833.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 573.2ms
# Speed: 4.8ms preprocess, 573.2ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 15 players, 1 referee, 1 ball, 930.0ms
# Speed: 5.2ms preprocess, 930.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 498.4ms
# Speed: 4.3ms preprocess, 498.4ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 players, 1 referee, 877.6ms
# Speed: 5.4ms preprocess, 877.6ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 LMC, 435.9ms
# Speed: 5.8ms preprocess, 435.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 players, 1 referee, 857.4ms
# Speed: 4.6ms preprocess, 857.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 LMC, 542.0ms
# Speed: 4.1ms preprocess, 542.0ms inference, 3.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 13 players, 1 referee, 1 ball, 949.2ms
# Speed: 5.8ms preprocess, 949.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 LMC, 520.7ms
# Speed: 4.1ms preprocess, 520.7ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 13 players, 1 referee, 1 ball, 1265.9ms
# Speed: 4.2ms preprocess, 1265.9ms inference, 13.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 LMC, 600.7ms
# Speed: 7.3ms preprocess, 600.7ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 players, 1 referee, 1 ball, 966.2ms
# Speed: 4.4ms preprocess, 966.2ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 494.8ms
# Speed: 8.0ms preprocess, 494.8ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 players, 1 referee, 1 ball, 850.3ms
# Speed: 4.2ms preprocess, 850.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 461.7ms
# Speed: 4.1ms preprocess, 461.7ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 13 players, 1 referee, 825.6ms
# Speed: 5.6ms preprocess, 825.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 LMC, 434.6ms
# Speed: 5.4ms preprocess, 434.6ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 players, 1 referee, 859.4ms
# Speed: 5.1ms preprocess, 859.4ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 LMC, 540.9ms
# Speed: 5.3ms preprocess, 540.9ms inference, 2.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 players, 1 referee, 892.9ms
# Speed: 5.8ms preprocess, 892.9ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 495.2ms
# Speed: 5.4ms preprocess, 495.2ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 players, 1 referee, 887.9ms
# Speed: 7.0ms preprocess, 887.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 733.9ms
# Speed: 6.0ms preprocess, 733.9ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 players, 1 referee, 1198.8ms
# Speed: 5.8ms preprocess, 1198.8ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 484.7ms
# Speed: 6.2ms preprocess, 484.7ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 players, 1 referee, 884.2ms
# Speed: 4.2ms preprocess, 884.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 472.3ms
# Speed: 4.9ms preprocess, 472.3ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 15 players, 1 referee, 1021.8ms
# Speed: 5.2ms preprocess, 1021.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 475.7ms
# Speed: 4.7ms preprocess, 475.7ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 players, 1 referee, 1202.1ms
# Speed: 5.9ms preprocess, 1202.1ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 495.9ms
# Speed: 4.8ms preprocess, 495.9ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 players, 1 referee, 1079.7ms
# Speed: 4.6ms preprocess, 1079.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 469.4ms
# Speed: 6.9ms preprocess, 469.4ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 players, 1 referee, 887.1ms
# Speed: 4.4ms preprocess, 887.1ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 481.2ms
# Speed: 5.8ms preprocess, 481.2ms inference, 2.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 players, 1 referee, 1074.2ms
# Speed: 5.8ms preprocess, 1074.2ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 494.7ms
# Speed: 6.0ms preprocess, 494.7ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 13 players, 1 referee, 896.9ms
# Speed: 4.2ms preprocess, 896.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 513.4ms
# Speed: 6.7ms preprocess, 513.4ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 players, 1 referee, 900.3ms
# Speed: 4.0ms preprocess, 900.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 462.4ms
# Speed: 4.3ms preprocess, 462.4ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 13 players, 1 referee, 999.9ms
# Speed: 4.4ms preprocess, 999.9ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 499.3ms
# Speed: 7.0ms preprocess, 499.3ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 13 players, 1 referee, 887.1ms
# Speed: 6.2ms preprocess, 887.1ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 463.6ms
# Speed: 4.5ms preprocess, 463.6ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 13 players, 1 referee, 1088.2ms
# Speed: 4.2ms preprocess, 1088.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 493.1ms
# Speed: 5.2ms preprocess, 493.1ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 13 players, 1 referee, 964.5ms
# Speed: 6.3ms preprocess, 964.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 486.8ms
# Speed: 4.5ms preprocess, 486.8ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 13 players, 1 referee, 899.5ms
# Speed: 5.1ms preprocess, 899.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 509.6ms
# Speed: 4.2ms preprocess, 509.6ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 13 players, 1 referee, 914.3ms
# Speed: 4.4ms preprocess, 914.3ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 496.7ms
# Speed: 4.1ms preprocess, 496.7ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 13 players, 1 referee, 1 ball, 1075.9ms
# Speed: 5.5ms preprocess, 1075.9ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 497.8ms
# Speed: 4.1ms preprocess, 497.8ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 13 players, 1 referee, 939.7ms
# Speed: 4.2ms preprocess, 939.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 LMC, 484.8ms
# Speed: 5.4ms preprocess, 484.8ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 players, 1 referee, 1 ball, 858.3ms
# Speed: 5.2ms preprocess, 858.3ms inference, 2.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 553.8ms
# Speed: 4.1ms preprocess, 553.8ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 players, 1 referee, 1 ball, 957.8ms
# Speed: 6.6ms preprocess, 957.8ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 468.9ms
# Speed: 4.8ms preprocess, 468.9ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 players, 1 referee, 1 ball, 1009.2ms
# Speed: 4.7ms preprocess, 1009.2ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 583.4ms
# Speed: 4.7ms preprocess, 583.4ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 players, 1 referee, 979.2ms
# Speed: 4.6ms preprocess, 979.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 580.0ms
# Speed: 4.2ms preprocess, 580.0ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 15 players, 1 referee, 954.6ms
# Speed: 4.3ms preprocess, 954.6ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 523.2ms
# Speed: 4.4ms preprocess, 523.2ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 13 players, 1 referee, 946.8ms
# Speed: 5.5ms preprocess, 946.8ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 484.7ms
# Speed: 5.4ms preprocess, 484.7ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 13 players, 1 referee, 913.5ms
# Speed: 4.2ms preprocess, 913.5ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 560.3ms
# Speed: 5.4ms preprocess, 560.3ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 13 players, 1 referee, 888.9ms
# Speed: 4.7ms preprocess, 888.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 486.0ms
# Speed: 5.0ms preprocess, 486.0ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 players, 1 referee, 901.4ms
# Speed: 5.4ms preprocess, 901.4ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 468.0ms
# Speed: 4.2ms preprocess, 468.0ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 players, 1 referee, 891.4ms
# Speed: 4.6ms preprocess, 891.4ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 577.2ms
# Speed: 4.3ms preprocess, 577.2ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 15 players, 1 referee, 902.0ms
# Speed: 5.1ms preprocess, 902.0ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 476.7ms
# Speed: 4.9ms preprocess, 476.7ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 players, 1 referee, 943.2ms
# Speed: 5.0ms preprocess, 943.2ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 472.6ms
# Speed: 4.1ms preprocess, 472.6ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 players, 1 referee, 916.2ms
# Speed: 4.5ms preprocess, 916.2ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 577.0ms
# Speed: 5.2ms preprocess, 577.0ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 13 players, 1 referee, 898.0ms
# Speed: 4.2ms preprocess, 898.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 485.2ms
# Speed: 4.9ms preprocess, 485.2ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 13 players, 1 referee, 921.3ms
# Speed: 6.6ms preprocess, 921.3ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 473.0ms
# Speed: 6.3ms preprocess, 473.0ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 13 players, 1 referee, 928.7ms
# Speed: 5.2ms preprocess, 928.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 611.8ms
# Speed: 4.2ms preprocess, 611.8ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 players, 1 referee, 941.6ms
# Speed: 4.3ms preprocess, 941.6ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 472.8ms
# Speed: 4.9ms preprocess, 472.8ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 15 players, 1 referee, 908.3ms
# Speed: 5.4ms preprocess, 908.3ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 500.0ms
# Speed: 4.9ms preprocess, 500.0ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 15 players, 1 referee, 1218.4ms
# Speed: 5.0ms preprocess, 1218.4ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 537.5ms
# Speed: 7.1ms preprocess, 537.5ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 players, 1 referee, 901.6ms
# Speed: 5.5ms preprocess, 901.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 474.1ms
# Speed: 4.8ms preprocess, 474.1ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 players, 1 referee, 901.1ms
# Speed: 4.1ms preprocess, 901.1ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 477.1ms
# Speed: 4.4ms preprocess, 477.1ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 15 players, 1 referee, 979.9ms
# Speed: 4.4ms preprocess, 979.9ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 511.0ms
# Speed: 6.9ms preprocess, 511.0ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 15 players, 1 referee, 909.5ms
# Speed: 4.9ms preprocess, 909.5ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 606.4ms
# Speed: 7.3ms preprocess, 606.4ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 players, 1 referee, 957.7ms
# Speed: 4.0ms preprocess, 957.7ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 470.8ms
# Speed: 4.4ms preprocess, 470.8ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 players, 1 referee, 1073.4ms
# Speed: 6.3ms preprocess, 1073.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 526.6ms
# Speed: 5.0ms preprocess, 526.6ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 players, 1 referee, 1012.1ms
# Speed: 4.6ms preprocess, 1012.1ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 576.4ms
# Speed: 5.1ms preprocess, 576.4ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 13 players, 1 referee, 1123.2ms
# Speed: 5.4ms preprocess, 1123.2ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 532.9ms
# Speed: 5.3ms preprocess, 532.9ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 players, 1 referee, 1054.3ms
# Speed: 6.8ms preprocess, 1054.3ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 548.2ms
# Speed: 4.6ms preprocess, 548.2ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 players, 1 referee, 1019.9ms
# Speed: 5.3ms preprocess, 1019.9ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 574.4ms
# Speed: 5.1ms preprocess, 574.4ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 15 players, 1 referee, 963.1ms
# Speed: 5.9ms preprocess, 963.1ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 610.2ms
# Speed: 4.6ms preprocess, 610.2ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 15 players, 1 referee, 929.9ms
# Speed: 4.9ms preprocess, 929.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 511.2ms
# Speed: 5.8ms preprocess, 511.2ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 15 players, 1 referee, 977.6ms
# Speed: 4.4ms preprocess, 977.6ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 509.9ms
# Speed: 4.6ms preprocess, 509.9ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 15 players, 1 referee, 995.0ms
# Speed: 4.7ms preprocess, 995.0ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 553.9ms
# ...
#
# 0: 320x640 (no detections), 560.1ms
# Speed: 4.1ms preprocess, 560.1ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 players, 1 referee, 832.6ms
# Speed: 4.0ms preprocess, 832.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 438.6ms
# Speed: 4.1ms preprocess, 438.6ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 players, 2 referees, 960.8ms
# Speed: 4.2ms preprocess, 960.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 463.7ms
# Speed: 4.1ms preprocess, 463.7ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 players, 1 referee, 810.3ms
# Speed: 4.8ms preprocess, 810.3ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 433.7ms
# Speed: 4.8ms preprocess, 433.7ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 players, 1 referee, 809.3ms
# Speed: 4.3ms preprocess, 809.3ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 504.3ms
# Speed: 4.2ms preprocess, 504.3ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 players, 1 referee, 843.7ms
# Speed: 4.2ms preprocess, 843.7ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 LMC, 587.4ms
# Speed: 6.5ms preprocess, 587.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 players, 1 referee, 900.3ms
# Speed: 5.4ms preprocess, 900.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 LMC, 452.4ms
# Speed: 4.2ms preprocess, 452.4ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 13 players, 1 referee, 825.7ms
# Speed: 4.5ms preprocess, 825.7ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 LMC, 552.9ms
# Speed: 36.2ms preprocess, 552.9ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 players, 2 referees, 846.9ms
# Speed: 4.1ms preprocess, 846.9ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 LMC, 519.9ms
# Speed: 6.1ms preprocess, 519.9ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 players, 2 referees, 851.8ms
# Speed: 5.3ms preprocess, 851.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 LMC, 457.6ms
# Speed: 5.2ms preprocess, 457.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 players, 1 referee, 828.3ms
# Speed: 4.1ms preprocess, 828.3ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 LMC, 451.6ms
# Speed: 4.0ms preprocess, 451.6ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 players, 1 referee, 952.2ms
# Speed: 6.3ms preprocess, 952.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 LMC, 499.8ms
# Speed: 4.1ms preprocess, 499.8ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 players, 1 referee, 846.6ms
# Speed: 4.3ms preprocess, 846.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 LMC, 569.7ms
# Speed: 5.1ms preprocess, 569.7ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 players, 2 referees, 820.5ms
# Speed: 4.8ms preprocess, 820.5ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 437.5ms
# Speed: 5.7ms preprocess, 437.5ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 players, 3 referees, 835.5ms
# Speed: 4.5ms preprocess, 835.5ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 467.9ms
# Speed: 4.0ms preprocess, 467.9ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 players, 2 referees, 1345.8ms
# Speed: 13.3ms preprocess, 1345.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 LMC, 606.3ms
# Speed: 7.1ms preprocess, 606.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 players, 2 referees, 1177.2ms
# Speed: 5.3ms preprocess, 1177.2ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 LMC, 673.6ms
# Speed: 6.5ms preprocess, 673.6ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 players, 1 referee, 1166.8ms
# Speed: 5.3ms preprocess, 1166.8ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 LMC, 720.5ms
# Speed: 6.5ms preprocess, 720.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 players, 1 referee, 1334.5ms
# Speed: 5.6ms preprocess, 1334.5ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 LMC, 638.9ms
# Speed: 6.7ms preprocess, 638.9ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 players, 1 referee, 1135.3ms
# Speed: 5.7ms preprocess, 1135.3ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 LMC, 681.8ms
# Speed: 6.1ms preprocess, 681.8ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 players, 1 referee, 1293.0ms
# Speed: 5.4ms preprocess, 1293.0ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 LMC, 647.7ms
# Speed: 6.9ms preprocess, 647.7ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 players, 1 referee, 1193.9ms
# Speed: 24.6ms preprocess, 1193.9ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 LMC, 673.0ms
# Speed: 4.3ms preprocess, 673.0ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 players, 1 referee, 1220.7ms
# Speed: 6.8ms preprocess, 1220.7ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 647.1ms
# Speed: 6.8ms preprocess, 647.1ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 players, 1 referee, 1208.1ms
# Speed: 5.5ms preprocess, 1208.1ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 695.0ms
# Speed: 5.1ms preprocess, 695.0ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 players, 1 referee, 1198.4ms
# Speed: 5.2ms preprocess, 1198.4ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 624.7ms
# Speed: 7.4ms preprocess, 624.7ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 players, 1 referee, 1085.1ms
# Speed: 7.4ms preprocess, 1085.1ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 LMC, 558.8ms
# Speed: 6.0ms preprocess, 558.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 players, 1136.6ms
# Speed: 4.9ms preprocess, 1136.6ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 LMC, 858.6ms
# Speed: 5.8ms preprocess, 858.6ms inference, 2.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 players, 1 referee, 1067.4ms
# Speed: 5.5ms preprocess, 1067.4ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 610.3ms
# Speed: 5.0ms preprocess, 610.3ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 players, 1160.0ms
# Speed: 7.1ms preprocess, 1160.0ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 LMC, 671.5ms
# Speed: 5.3ms preprocess, 671.5ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 players, 1159.0ms
# Speed: 7.4ms preprocess, 1159.0ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 LMC, 800.5ms
# Speed: 4.4ms preprocess, 800.5ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 players, 1372.5ms
# Speed: 5.6ms preprocess, 1372.5ms inference, 3.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 LMC, 747.7ms
# Speed: 4.6ms preprocess, 747.7ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 players, 2 referees, 1263.1ms
# Speed: 4.9ms preprocess, 1263.1ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 LMC, 935.4ms
# Speed: 7.0ms preprocess, 935.4ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 players, 1 referee, 1290.6ms
# Speed: 37.8ms preprocess, 1290.6ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 LMC, 628.2ms
# Speed: 5.8ms preprocess, 628.2ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 players, 1 referee, 1229.7ms
# Speed: 4.7ms preprocess, 1229.7ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 LMC, 596.3ms
# Speed: 6.9ms preprocess, 596.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 7 players, 2056.8ms
# Speed: 7.1ms preprocess, 2056.8ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 LMC, 866.2ms
# Speed: 6.9ms preprocess, 866.2ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 players, 2 referees, 1041.8ms
# Speed: 9.0ms preprocess, 1041.8ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 LMC, 476.5ms
# Speed: 6.1ms preprocess, 476.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 players, 2 referees, 985.5ms
# Speed: 4.5ms preprocess, 985.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 LMC, 511.4ms
# Speed: 4.2ms preprocess, 511.4ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 players, 3 referees, 992.1ms
# Speed: 5.0ms preprocess, 992.1ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 LMC, 597.8ms
# Speed: 4.6ms preprocess, 597.8ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 players, 3 referees, 1028.1ms
# Speed: 5.7ms preprocess, 1028.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 LMC, 678.3ms
# Speed: 4.3ms preprocess, 678.3ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 players, 3 referees, 1090.6ms
# Speed: 6.1ms preprocess, 1090.6ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 LMC, 518.3ms
# Speed: 5.4ms preprocess, 518.3ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 players, 3 referees, 1054.8ms
# Speed: 6.5ms preprocess, 1054.8ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 LMC, 598.9ms
# Speed: 5.2ms preprocess, 598.9ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 players, 3 referees, 1009.8ms
# Speed: 4.1ms preprocess, 1009.8ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 LMC, 507.8ms
# Speed: 4.1ms preprocess, 507.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 players, 3 referees, 965.7ms
# Speed: 4.7ms preprocess, 965.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 LMC, 508.8ms
# Speed: 5.4ms preprocess, 508.8ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 players, 2 referees, 1108.0ms
# Speed: 5.0ms preprocess, 1108.0ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 LMC, 526.4ms
# Speed: 5.8ms preprocess, 526.4ms inference, 2.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 players, 2 referees, 992.4ms
# Speed: 4.1ms preprocess, 992.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 LMC, 545.6ms
# Speed: 4.0ms preprocess, 545.6ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 players, 2 referees, 953.9ms
# Speed: 5.1ms preprocess, 953.9ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 LMC, 566.4ms
# Speed: 5.8ms preprocess, 566.4ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 players, 2 referees, 1062.0ms
# Speed: 5.6ms preprocess, 1062.0ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 LMC, 488.5ms
# Speed: 4.9ms preprocess, 488.5ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 players, 2 referees, 978.5ms
# Speed: 5.0ms preprocess, 978.5ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 LMC, 516.9ms
# Speed: 4.9ms preprocess, 516.9ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 players, 2 referees, 963.6ms
# Speed: 4.7ms preprocess, 963.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 LMC, 668.8ms
# Speed: 5.0ms preprocess, 668.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 players, 988.1ms
# Speed: 5.8ms preprocess, 988.1ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 LMC, 494.2ms
# Speed: 4.2ms preprocess, 494.2ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 players, 943.1ms
# Speed: 5.6ms preprocess, 943.1ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 LMC, 498.9ms
# Speed: 4.8ms preprocess, 498.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 players, 1 referee, 1018.9ms
# Speed: 4.3ms preprocess, 1018.9ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 LMC, 950.6ms
# Speed: 5.0ms preprocess, 950.6ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 players, 1 referee, 1199.0ms
# Speed: 5.7ms preprocess, 1199.0ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 LMC, 504.1ms
# Speed: 4.1ms preprocess, 504.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 players, 1 referee, 1298.8ms
# Speed: 7.1ms preprocess, 1298.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 LMC, 594.5ms
# Speed: 4.8ms preprocess, 594.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 players, 1 referee, 1221.2ms
# Speed: 5.4ms preprocess, 1221.2ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 LMC, 542.3ms
# Speed: 5.1ms preprocess, 542.3ms inference, 2.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 10 players, 2 referees, 1003.1ms
# Speed: 4.5ms preprocess, 1003.1ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 LMC, 512.2ms
# Speed: 4.2ms preprocess, 512.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 8 players, 3 referees, 1111.3ms
# Speed: 4.9ms preprocess, 1111.3ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 LMC, 689.5ms
# Speed: 4.6ms preprocess, 689.5ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 players, 1 referee, 1018.6ms
# Speed: 5.1ms preprocess, 1018.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 LMC, 558.3ms
# Speed: 5.6ms preprocess, 558.3ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 9 players, 3 referees, 1180.5ms
# Speed: 5.9ms preprocess, 1180.5ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 LMCs, 531.1ms
# Speed: 4.2ms preprocess, 531.1ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 11 players, 2 referees, 1105.0ms
# Speed: 7.4ms preprocess, 1105.0ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 LMC, 502.9ms
# Speed: 5.2ms preprocess, 502.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
